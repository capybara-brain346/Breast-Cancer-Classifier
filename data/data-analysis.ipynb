# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"../data/Breast Cancer Classification/breast-cancer-wisconsin-data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
columns = [i for i in data.columns]

# %%
columns[12:22]
# Out:
# ['radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se']

# %%
data = data.drop(columns[12:22],axis=1)

# %%
data = data.drop(['id'],axis=1)

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['target'] = le.fit_transform(data['diagnosis'])

# %%
data = data.drop(['diagnosis'],axis=1)

# %%
data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data.target.unique()
# Out:
# array([1, 0])

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
data = data.drop(['radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
       'smoothness_worst', 'compactness_worst', 'concavity_worst',
       'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'],axis=1)

# %%
sns.heatmap(data.corr(),annot=True,linewidths=.5)
plt.show()

# %%
data = data.drop(['perimeter_mean'],axis=1)

# %%
sns.displot(data=data, x="target", kind='hist')
# Out:
# c:\Users\piyus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data=data,x='target',y='area_mean')
# Out:
# c:\Users\piyus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\piyus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data.to_json()
# Out:
# '{"radius_mean":{"0":17.99,"1":20.57,"2":19.69,"3":11.42,"4":20.29,"5":12.45,"6":18.25,"7":13.71,"8":13.0,"9":12.46,"10":16.02,"11":15.78,"12":19.17,"13":15.85,"14":13.73,"15":14.54,"16":14.68,"17":16.13,"18":19.81,"19":13.54,"20":13.08,"21":9.504,"22":15.34,"23":21.16,"24":16.65,"25":17.14,"26":14.58,"27":18.61,"28":15.3,"29":17.57,"30":18.63,"31":11.84,"32":17.02,"33":19.27,"34":16.13,"35":16.74,"36":14.25,"37":13.03,"38":14.99,"39":13.48,"40":13.44,"41":10.95,"42":19.07,"43":13.28,"44":13.17,"45":18.65,"46":8.196,"47":13.17,"48":12.05,"49":13.49,"50":11.76,"51":13.64,"52":11.94,"53":18.22,"54":15.1,"55":11.52,"56":19.21,"57":14.71,"58":13.05,"59":8.618,"60":10.17,"61":8.598,"62":14.25,"63":9.173,"64":12.68,"65":14.78,"66":9.465,"67":11.31,"68":9.029,"69":12.78,"70":18.94,"71":8.888,"72":17.2,"73":13.8,"74":12.31,"75":16.07,"76":13.53,"77":18.05,"78":20.18,"79":12.86,"80":11.45,"81":13.34,"82":25.22,"83":19.1,"84":12.0,"85":18.46,"86":14.48,"87":19.02,"88":12.36,"89":14.64,"90":14.
# ...

# %%
data.to_csv("model_training_data.csv",index=False)
